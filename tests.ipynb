# %%
from risk import Risk

# %%
game = Risk()

# %%
game.global_map
# Out:
# {'EUROPE': 0,
#  'ASIA': 0,
#  'OCEANIA': 0,
#  'NORTH AMERICA': 0,
#  'SOUTH AMERICA': 0,
#  'AFRICA': 0}

# %%
player1_map = {'EUROPE': 0, 'ASIA': 0, 'OCEANIA': 1, 'NORTH AMERICA': 0, 'SOUTH AMERICA': 0, 'AFRICA': 0}
game.add_player('Sion', player1_map)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-c617426c7d8e> in <module>()
#       1 player1_map = {'EUROPE': 0, 'ASIA': 0, 'OCEANIA': 1, 'NORTH AMERICA': 0, 'SOUTH AMERICA': 0, 'AFRICA': 0}
# ----> 2 game.add_player('Sion', player1_map)
#
# ~\Documents\Python Scripts\Risk\risk.py in add_player(self, player, armies)
#      36         if not self.players:
#      37             self.players.append(player)
# ---> 38             self.players_map[player] = Map(armies=armies)
#      39             self._update_global_map(armies)
#      40
#
# ~\Documents\Python Scripts\Risk\map.py in __init__(self, armies)
#      21             self.global_map = self.base_map
#      22         else:
# ---> 23           self.global_map = dict(Counter(self.base_map).update(armies))
#      24
#      25         self.connections = {('EUROPE', 'ASIA'),
#
# ...

# %%
game.players_map
# Out:
# {'biel': {'SOUTH AMERICA': 2},
#  'Sion': {'EUROPE': 0,
#   'ASIA': 0,
#   'OCEANIA': 1,
#   'NORTH AMERICA': 0,
#   'SOUTH AMERICA': 0,
#   'AFRICA': 0}}

# %%
game.global_map
# Out:
# {'EUROPE': 5,
#  'ASIA': 3,
#  'OCEANIA': 0,
#  'NORTH AMERICA': 0,
#  'SOUTH AMERICA': 0,
#  'AFRICA': 0}

# %%
game.add_player('Sion', player1_map)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-0879d24b7b14> in <module>()
# ----> 1 game.add_player('Sion', player1_map)
#
# ~\Documents\Python Scripts\Risk\risk.py in add_player(self, player, armies)
#      49                 if units > 0:
#      50                     if country in occupied_countries:
# ---> 51                         raise ValueError(f'Country {country} already occupied by other player')
#      52
#      53             self.players.append(player)
#
# ValueError: Country EUROPE already occupied by other player

# %%
game
# Out:
# {'biel': {'EUROPE': 5, 'ASIA': 3, 'OCEANIA': 0, 'NORTH AMERICA': 0, 'SOUTH AMERICA': 0, 'AFRICA': 0}, 'Sion': {'EUROPE': 5, 'ASIA': 3, 'OCEANIA': 0, 'NORTH AMERICA': 0, 'SOUTH AMERICA': 0, 'AFRICA': 0}}

# %%
player1_map
# Out:
# {'EUROPE': 0,
#  'ASIA': 0,
#  'OCEANIA': 1,
#  'NORTH AMERICA': 0,
#  'SOUTH AMERICA': 0,
#  'AFRICA': 0}

# %%
map2 = {'AFRICA': 3}

# %%
from collections import Counter

# %%
map1 = Counter(player1_map)

# %%
map1.update(map2)

# %%
map1
# Out:
# Counter({'EUROPE': 0,
#          'ASIA': 0,
#          'OCEANIA': 1,
#          'NORTH AMERICA': 0,
#          'SOUTH AMERICA': 0,
#          'AFRICA': 9})

# %%
dict(map1)
# Out:
# {'EUROPE': 0,
#  'ASIA': 0,
#  'OCEANIA': 1,
#  'NORTH AMERICA': 0,
#  'SOUTH AMERICA': 0,
#  'AFRICA': 9}

# %%
import pandas as pd
import numpy as np

# %%
nodes = pd.read_csv('resources/risk_nodes.csv', index_col=0)

# %%
nodes
# Out:
#                      name          group
# 1                  Alaska  North America
# 2                 Alberta  North America
# 3         Central America  North America
# 4   Eastern United States  North America
# 5               Greenland  North America
# 6     Northwest Territory  North America
# 7                 Ontario  North America
# 8                  Quebec  North America
# 9   Western United States  North America
# 10              Argentina  South America
# 11                 Brazil  South America
# 12                   Peru  South America
# 13              Venezuela  South America
# 14          Great Britain         Europe
# 15                Iceland         Europe
# 16        Northern Europe         Europe
# 17            Scandinavia         Europe
# 18        Southern Europe         Europe
# 19                Ukraine         Europe
# 20         Western Europe         Europe
# 21         Central Africa         Africa
# 22            East Africa         Africa
# ...

# %%
links = pd.read_csv('resources/risk_links.csv', index_col=0)

# %%
nodes_dict = {value:key for value, key in enumerate(nodes.name)}

# %%
nodes_dict
# Out:
# {0: 'Alaska',
#  1: 'Alberta',
#  2: 'Central America',
#  3: 'Eastern United States',
#  4: 'Greenland',
#  5: 'Northwest Territory',
#  6: 'Ontario',
#  7: 'Quebec',
#  8: 'Western United States',
#  9: 'Argentina',
#  10: 'Brazil',
#  11: 'Peru',
#  12: 'Venezuela',
#  13: 'Great Britain',
#  14: 'Iceland',
#  15: 'Northern Europe',
#  16: 'Scandinavia',
#  17: 'Southern Europe',
#  18: 'Ukraine',
#  19: 'Western Europe',
#  20: 'Central Africa',
#  21: 'East Africa',
#  22: 'Egypt',
#  23: 'Madagascar',
#  24: 'North Africa',
#  25: 'South Africa',
#  26: 'Afghanistan',
#  27: 'China',
#  28: 'India',
#  29: 'Irkutsk',
#  30: 'Japan',
#  31: 'Kamchatka',
#  32: 'Middle East',
#  33: 'Mongolia',
#  34: 'Siam',
#  35: 'Siberia',
#  36: 'Ural',
#  37: 'Yakutsk',
#  38: 'Eastern Australia',
#  39: 'Indonesia',
#  40: 'New Guinea',
#  41: 'Western Australia'}

# %%
links = links.apply(lambda x: x.map(nodes_dict))

# %%
links
# Out:
#                    source                 target
# 1                  Alaska                Alberta
# 2                  Alaska    Northwest Territory
# 3                 Alberta    Northwest Territory
# 4                 Alberta                Ontario
# 5                 Alberta  Western United States
# 6         Central America  Western United States
# 7         Central America  Eastern United States
# 8   Eastern United States                Ontario
# 9   Eastern United States                 Quebec
# 10  Eastern United States  Western United States
# 11              Greenland    Northwest Territory
# 12              Greenland                Ontario
# 13              Greenland                 Quebec
# 14    Northwest Territory                Ontario
# 15                Ontario                 Quebec
# 16                Ontario  Western United States
# 17              Venezuela        Central America
# 18              Venezuela                 Brazil
# ...
